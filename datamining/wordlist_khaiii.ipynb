# %%
import pandas as pd
import numpy as np
from khaiii import KhaiiiApi
import gensim
import pyLDAvis.gensim
import numpy as np
import logging
from gensim.models.coherencemodel import CoherenceModel
import matplotlib.pyplot as plt
import time
from pprint import pprint

# %%
data = pd.read_csv("./modi_data/kor_full.csv") ############
#data = data.drop(['Unnamed: 0'], axis=1)
data.head()
# Out:
# /Users/uni613/Library/Python/3.8/lib/python/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     no  year                                           kor_full
# 0  137  2002  탐색 알고리즘 교육을 위한 S/W 컴포넌트의 개발 탐색알고리즘교육, 컴퓨터프로그래밍...
# 1  147  2002  프로젝트 학습을 기반으로 하는 ICT 활용 수업 모형의 개발 및 적용 ICT 활용교...
# 2  148  2002  분산 컴퓨팅 환경에서의 웹 교육 컴포넌트 개발과정 모델링 웹기반 교육, 컴포넌트 개...
# 3  149  2002  효과적인 아동용 WBI를 위한 한글 타이포그래피의 가해성 분석과 활용 타이포 그래피...
# 4  150  2002  교수 · 학습 디지털 컨텐트 통합메타데이터 및 개체-관계 모델 설계 교수.학습, 컨...

# %%
dfWordList = pd.read_excel("./word_cor.xlsx")
#print(dfWordList)

dfWordDel = dfWordList[dfWordList["수정"] == "삭제"]
dfWordMod = dfWordList[dfWordList["수정"] != "삭제"]
#print(dfWordMod)

seriesDelete = dfWordDel["원본"]
stopword = []
for word in seriesDelete.values:
    stopword.append(word)
#print(stopword)

seriesModify = dfWordMod["원본"]
modiword = []
for word in seriesModify.values:
    modiword.append(word)
#print(len(modiword))

seriesModify2 = dfWordMod["수정"]
modiword2 = []
for word in seriesModify2.values:
    modiword2.append(word)
#print(len(modiword2))
# Out:
# /Users/uni613/Library/Python/3.8/lib/python/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
api = KhaiiiApi()
def khaiiiTokenizer(raw, stopword=stopword, pos=['NNG', 'NNP', 'NNB', 'NP', 'NR', 'SL']): # 일반명사 고유명사 의존명사 대명사 수사 외국어
    list = []
    
    for word in api.analyze(raw): #raw data
        #print(word)
        
        for morph in word.morphs:
            #print(morph.lex)
            if morph.tag in pos and morph.lex not in stopword: 
                if morph.tag == 'SL':
                   morph.lex = word.lower()
                if morph.lex in modiword:
                    morph.lex = modiword2[modiword.index(morph.lex)]
                list.append(morph.lex)
    return list
# Out:
# /Users/uni613/Library/Python/3.8/lib/python/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
tokenized = data["kor_full"].apply(lambda row: khaiiiTokenizer(row))
#print(tokenized)
tokenized.to_excel("./final_data/1206token_khaiii_full.xls") ##############
print("========= tokenization completed =========")
# Out:
# 하
# 였
# 다
# .
# 연구
# 결과
# 에
# 따르
# 면
# 환경
# 측면
# 의
# 실습실
# 요인
# 을
# 제외
# 하
# ㄴ
# 모든
# 요인
# (
# 컴퓨터
# 자기
# 효능감
# ,
# 혁신
# 성
# ,
# 동기
# ,
# 자
# 기
# 조절
# 효능감
# ,
# 교수자
# 특성
# )
# 이
# 정보
# 교육
# 성과
# 에
# 유의
# 하
# ㄴ
# 영향
# 을
# 미치
# 는
# 것
# 으로
# 나타나
# 았
# 다
# .
# 대학
# 에서
# 의
# 정보
# 교육
# 성과
# 에
# 영향
# 을
# 미치
# 는
# 요인
# 은
# 분석
# 은
# 정보
# 화
# 사회
# 의
# 인재
# 양성
# 에
# 기여
# 하
# ㄹ
# 수
# 있
# 으며
# 효과
# 적
# 이
# ㄴ
# 정보
# 교육
# 을
# 위하
# ㄴ
# 지침
# 을
# 제공
# 하
# 여
# 주
# ㄹ
# 수
# 있
# 을
# 것
# 이
# 다
# .
# 효율
# 적
# 이
# ㄴ
# 초등학교
# 정보
# 통신
# 윤리
# 교육
# 을
# 위하
# ㄴ
# 맞춤
# 형
# 교육
# 지원
# 시스템
# 개발
# 및
# 적용
# 정보
# 통신
# 윤리교육
# ,
# 맞춤
# 형
# 교육
# 지원
# 시스템
# 현실
# 에서
# 경험
# 하
# 거나
# 당면
# 하
# 고
# 있
# 는
# 실제
# 적
# 이
# ㄴ
# 문제
# 를
# 해결
# 하
# ㄹ
# 때
# 학습자
# 는
# 학습
# 의
# 의미
# 를
# 느끼
# 며
# 학습
# 의
# 효과
# 도
# 기대
# 하
# ㄹ
# 수
# 있
# 다
# .
# 따라서
# 초등학교
# 에서
# 일어나
# ㄹ
# 수
# 있
# 는
# 정보
# 통신
# 윤리
# 교육
# 지도
# 상황
# 에
# 따르
# 아
# 교사
# 에게
# 필요
# 하
# ㄴ
# 자료
# 들
# 을
# 웹상
# 에서
# 제공
# 하
# 는
# 맞춤
# 형
# 정보
# 통신
# 윤리
# 교육
# 지원
# 시스템
# 을
# 개발
# 하
# 였
# 다
# .
# 개발
# 하
# ㄴ
# 시스템
# 에서
# 는
# 정보
# 통신
# 윤리
# 교육
# 의
# 방법
# 과
# 자료
# 및
# 그
# 활용
# 방법
# 을
# 제공
# 하
# 고
# 있
# 다
# .
# 시스템
# 은
# 주제
# 별
# 로
# 맞춤
# 형
# 자료
# 를
# 제공
# 하
# ㅁ
# 으로써
# 실제
# 상황
# 에
# 적절
# 하
# ㄴ
# 정보
# 통신
# 윤리
# 교육
# 을
# 실시
# 하
# 는데
# 도움
# 이
# 되
# 었
# 다
# .
# 또한
# 주제
# 와
# 지원
# 하
# 는
# 자료
# 의
# 적합
# 정도
# 를
# 알리
# 어
# 주
# 어
# 다음
# 사용자
# 가
# 자료
# 를
# 선택
# 하
# 는데
# 도움
# 이
# 되
# 었
# 으며
# ,
# 교사
# 의
# 지도
# 자료
# 검색
# 에
# 대하
# ㄴ
# 부담
# 을
# 덜
# 어
# 주
# 었
# 다
# .
# 스마
# 트
# 폰
# 가속
# 도
# 센서
# 를
# 이용
# 하
# ㄴ
# 숫자
# 인식
# 가속기
# ,
# 보정
# 및
# 분류
# ,
# 제스처
# 인식
# 본
# 연구
# 에서
# 는
# 가속
# 도
# 센서
# 의
# 각
# 축
# 의
# 값
# 들
# 을
# 이용
# 하
# 여
# 숫자
# 나
# 특정
# 입력
# 값
# 을
# 기기
# 에
# 전달
# 하
# ㄹ
# 수
# 있
# 는
# 제스처
# 인식
# 을
# 위하
# ㄴ
# 센서
# 값
# 들
# 의
# 효율
# 적
# 이
# ㄴ
# 사전
# 보정
# 알고리즘
# 과
# 분류
# 알고리즘
# 에
# 대하
# 여서
# 제안
# 하
# ㄴ다
# .
# 실험결과
# 보정
# 전
# 과
# 보정
# 후
# 의
# X
# 축
# 과
# Z
# 축
# 의
# 에러
# 율
# 을
# 통하
# 여
# 전처리
# 되
# ㄴ
# 데이터
# 가
# 생성
# 되
# ㅁ
# 을
# 알
# ㄹ
# 수
# 있
# 었
# 다
# .
# 또한
# 전처리
# 되
# ㄴ
# 데이터
# 에
# 적용
# 하
# ㄹ
# 정규
# 화
# 와
# 분류
# 알고리즘
# 으로
# 구현
# 하
# ㄴ
# 인식기
# 가
# 높
# 은
# 인식
# 률
# 을
# 보이
# 어
# 주
# 었
# 다
# .
# 협동
# 학습
# 을
# 통하
# ㄴ
# 웹
# 기반
# 영어
# 쓰
# 기
# 시스템
# 개발
# 및
# 적용
# 웹
# 기반
# 교육
# ,
# 영어
# 쓰
# 기
# 학습
# ,
# 협동
# 학습
# 현재
# 초등학교
# 에서
# 는
# 이루어지
# 는
# 영어
# 교육
# 은
# 기본
# 적
# 이
# ㄴ
# 의사소통
# 능력
# 을
# 기르
# 기
# 위하
# 여
# 언어
# 의
# 4
# 기능
# (
# 듣
# 기
# ,
# 말
# 하
# 기
# ,
# 읽
# 기
# ,
# 쓰
# 기
# )
# 을
# 통합
# 적
# 으로
# 사용
# 하
# ㄹ
# 수
# 있
# 도록
# 내용
# 이
# 구성
# 되
# 어
# 있
# 다
# .
# 그러나
# 6
# 학년
# 영어
# 쓰
# 기
# 학습
# 내용
# 의
# 구성
# 을
# 보
# 면
# ,
# 영어
# 문장
# 쓰
# 기
# 학습
# 은
# 하
# 고
# 있
# 으나
# 단순히
# 문장
# 따르
# 아
# 쓰
# 기
# ,
# 단어
# 넣
# 어
# 문장
# 완성
# 하
# 기
# 등
# 으로
# 한정
# 되
# 어
# 있
# 고
# ,
# 영어
# 쓰
# 기
# 학습
# 을
# 하
# ㄹ
# 시간
# 이
# 절대
# 적
# 으로
# 부족
# 하
# 다
# .
# 또한
# ,
# 학생
# 들
# 의
# 영어
# 쓰
# 기
# 학습
# 은
# 영어
# 단어
# 암기
# 학습
# 으로
# 생각
# 하
# 여
# 영어
# 쓰
# 기
# 학습
# 에
# 대하
# 여
# 부정
# 적
# 이
# ㄴ
# 생각
# 을
# 가지
# 고
# 있
# 다
# .
# 이러
# 하
# ㄴ
# 문제점
# 을
# 해결
# 하
# 기
# 위하
# 여
# 보
# ㄴ
# 연구자
# 는
# 웹
# 을
# 기반
# 으로
# 한
# 협동
# 영어
# 쓰
# 기
# 학습
# 시스템
# 을
# 개발
# 하
# 여
# 시간
# 과
# 장소
# 의
# 제약
# 없이
# 정규
# 수업
# 시간
# 외
# 에
# 방
# 과
# 후
# 시간
# 또는
# 가정
# 에서
# 학습
# 하
# ㄹ
# 수
# 있
# 도록
# 하
# 였
# 다
# .
# 또한
# ,
# 학생
# 들
# 은
# 시스템
# 을
# 활용
# 하
# 여
# 자신
# 의
# 생각
# 을
# 영어
# 로
# 표현
# 하
# 고
# ,
# 동료
# 들
# 과
# 의
# 협동
# 학습
# 을
# 통하
# 여
# 영어
# 쓰
# 기
# 활동
# 에
# 적극
# 적
# 으로
# 참여
# 하
# ㄴ
# 결과
# 영어
# 쓰
# 기
# 의
# 정의
# 적
# 영역
# 과
# 영어
# 쓰
# 기
# 능력
# 에
# 향상
# 되
# 었
# 다
# .
# 무선
# 이동
# 인터넷
# 에서
# 계층
# 이동
# 성
# 관리
# 기법
# 의
# 성능
# 평가
# 무선
# 모바일
# 인터넷
# ,
# 이동
# 성
# 관리
# 기법
# ,
# 핸드오버
# ,
# 모바일
# IP
# ,
# SCTP
# 본
# 연구
# 는
# 무선
# 이동
# 인터넷
# 에서
# 사용
# 가능
# 하
# ㄴ
# 계층
# 별
# 이동
# 성
# 관리
# 기법
# 의
# 핸드오버
# 절차
# 와
# 성능
# 을
# 비교
# 하
# ㄴ
# 것
# 이
# 다
# .
# 이동
# 환경
# 에서
# 무
# 결
# 정
# 성
# 의
# 정보
# 서비스
# 를
# 제공
# 하
# 기
# 위하
# ㄴ
# 효율
# 적
# 이
# ㄴ
# 이동
# 성
# 관리
# 기법
# 을
# 조사
# 하
# 기
# 위하
# 여
# 먼저
# 기존
# 의
# 네트워크
# 계층
# 에서
# 의
# 이동
# 성
# 지원
# 기법
# 이
# ㄴ
# 모바일
# IPv
# 4
# 와
# 모바일
# IPv
# 6
# 에
# 대하
# ㄴ
# 핸드오버
# 절차
# 를
# 설명
# 하
# 고
# ,
# 이어서
# 트랜스포트
# 계층
# 에서
# 의
# 이동
# 성
# 지원
# 기법
# 이
# ㄴ
# SCTP
# 에
# 기반
# 하
# ㄴ
# 모바일
# 구조
# (
# SMA
# )
# 의
# 핸드오버
# 절차
# 를
# 비교
# 하
# ㄴ다
# .
# NS
# -
# 2
# 를
# 이용
# 하
# 여
# 무선
# 이동
# 환경
# 에서
# 모바일
# IPv
# 6
# 와
# SMA
# 의
# 성능
# 을
# 비교
# 하
# ㄴ
# 시뮬레이션
# 결과
# 는
# SMA
# 가
# 핸드오버
# 지연
# 시간
# ,
# 패킷
# 손실
# 률
# 그리고
# 처리
# 율
# 에서
# Mobile
# IPv
# 6
# 보다
# 우수
# 하
# ㅁ
# 을
# 보이
# 었
# 다
# .
# 놀이
# 를
# 통하
# ㄴ
# 논리
# 적
# 사고력
# 신장
# 알고리즘
# 학습
# 프로그램
# 개발
# 및
# 적용
# 연구
# 컴퓨터
# 교육
# ,
# 알고리즘
# 학습
# ,
# 놀이
# 를
# 통하
# ㄴ
# 학습
# ,
# 논리
# 적
# 사고력
# 본
# 논문
# 에서
# 는
# 초등학생
# 의
# 인지
# 수준
# 에
# 적합
# 하
# ㄴ
# 알고리즘
# 학습
# 주제
# 를
# 선정
# 하
# 고
# ,
# 교실
# 에서
# 학습
# 하
# ㄹ
# 수
# 있
# 는
# 놀이
# 중심
# 의
# 알고리즘
# 학습
# 프로그램
# 을
# 개발
# 하
# 였
# 다
# .
# 또한
# 개발
# 하
# ㄴ
# 학습
# 프로그램
# 을
# 실제
# 교육
# 현장
# 에
# 적용
# 하
# 여
# 논리
# 적
# 사
# 고력
# 향상
# 에
# 긍정
# 적
# 이
# ㄴ
# 효과
# 가
# 있
# 는지
# 검증
# 하
# 였
# 다
# .
# 연구
# 결과
# 개발
# 하
# ㄴ
# 놀이중심
# 알고리즘
# 학습
# 프로그램
# 을
# 적용
# 하
# ㄴ
# 수업
# 이
# 기존
# ICT
# 활용
# 수업
# 에
# 비하
# 여
# 논리
# 적
# 사고력
# 신장
# 면
# 에서
# 유의
# 하
# ㄴ
# 차이
# 가
# 나타나
# 았
# 다
# .
# 이
# 는
# 놀이
# 중심
# 의
# 알고리즘
# 학습
# 이
# 논리
# 적
# 사고력
# 향상
# 에
# 긍정
# 적
# 이
# ㄴ
# 영향
# 을
# 주
# ㄴ
# 것
# 으로
# 해석
# 하
# ㄹ
# 수
# 있
# 다
# .
# 학교
# 컴퓨터실
# 을
# 위하
# ㄴ
# PC
# 실행
# 프로세스
# 모니터링
# 시스템
# 의
# 설계
# 및
# 구현
# 실행
# 프로세스
# ,
# 모니터링
# 시스템
# PC
# 사용
# 을
# 제어
# 하
# 고
# 관리
# 하
# 기
# 위하
# 여
# 각
# PC
# 에서
# 실행
# 하
# 는
# 프로세스
# 를
# 모니터링
# 하
# 는
# 시스템
# 에
# 대하
# ㄴ
# 연구
# 는
# 여러
# 형태
# 로
# 이루어지
# 어
# 오
# 았
# 다
# .
# 그러나
# 다수
# PC
# 에서
# 각
# PC
# 의
# 실행
# 프로세스
# 를
# 모니터링
# 하
# 고
# 파일
# 로
# 레포팅
# 하
# 는
# 방식
# 의
# 시스템
# 에
# 대하
# ㄴ
# 연구
# 는
# 찾아보
# 기
# 어렵
# ㄴ
# 실정
# 이
# 다
# .
# 이
# 에
# 보
# ㄴ
# 연구
# 에서
# 는
# 다수
# PC
# 환경
# 에서
# 각
# PC
# 를
# 모니터링
# 하
# 고
# 서버
# 로
# 파일
# 레포팅
# 하
# 고
# ,
# 레포팅
# 정보
# 를
# 수합
# ㆍ
# 정리
# 하
# 는
# 기능
# 을
# 갖
# 는
# 시스템
# 을
# 설계
# 및
# 구현
# 하
# 고자
# 하
# ㄴ다
# .
# 본
# 연구
# 의
# 시스템
# 을
# 이용
# 하
# ㄹ
# 경우
# 각
# PC
# 를
# 사용
# 하
# 는
# 학습자
# 는
# 실행
# 프로세스
# 가
# 관리자
# 에게
# 레포팅
# 되
# ㄴ다는
# 것
# 을
# 인지
# 하
# 게
# 되
# 어
# 불
# 필요
# 하
# ㄴ
# 프로세스
# 실행
# 을
# 자제
# 하
# 는
# 효과
# 를
# 가져오
# ㄹ
# 수
# 있
# 을
# 것
# 으로
# 기대
# 하
# ㄴ다
# .
# 재량
# 활동
# 시간
# 에
# 창의
# 성
# 학습
# 활동
# 을
# 위하
# ㄴ
# 비프로그램
# 형
# 라인트레이서
# 학습
# 모
# 형
# -
# 교재
# 개발
# 과
# 수행
# 평가
# 중심
# -
# 로봇
# ,
# 라인트레
# 이
# 서
# ,
# 교육
# 과정
# 과
# 교재
# ,
# 평가
# 대부분
# 의
# 로봇
# 학습
# 도구
# 가
# 성적
# 및
# 사교육능력
# 이
# 우수
# 하
# ㄴ
# 집단
# 학생
# 들
# 의
# 창의
# 성
# 교구
# 로
# 사용
# 되
# 고
# 있
# 으며
# 아직
# ,
# 재량
# 활동
# 시간
# 등
# 의
# 정규
# 교
# 과
# 수업
# 에
# 접목
# 하
# 여
# 사용
# 되
# 고
# 있
# 지
# 않
# 다
# .
# 본
# 연구
# 는
# 비교
# 적
# 저렴
# 하
# ㄴ
# 라인트레이서
# 를
# 교구
# 로
# 사용
# 하
# 여
# 학업
# 성취도
# 가
# 평균
# 이하
# 이
# ㄴ
# 초등학생
# 5
# 학년
# 들
# 이
# 정규교과목
# 과
# 연계
# 하
# 여
# 로봇
# 학습
# 을
# 하
# ㄹ
# 수
# 있
# 도록
# 12
# 차
# 시
# 분량
# 의
# 교육
# 과정
# 과
# 교재
# 를
# 개발
# 하
# 였
# 다
# .
# 최적성
# 을
# 확인
# 하
# 기
# 위하
# 여
# 학업
# 성취
# 수준
# 이
# 학년
# 평균
# 이하
# 의
# 학생
# 들
# 을
# 대상
# 으로
# 학습
# 시키
# ㄴ
# 후
# 평가
# 하
# 였
# 다
# .
# 각
# 차시
# 별
# 학습
# 결과
# 를
# 산출물
# 중심
# 으로
# 성취
# 수준
# 을
# 평가
# 하
# ㄴ
# 결과
# 로
# 학업
# 성취도
# 가
# 낮
# 은
# 학생
# 들
# 이
# 대부분
# 의
# 교육
# 과정
# 내용
# 을
# 충분히
# 이해
# 하
# 는
# 수준
# 으로
# 평가
# 되
# 었
# 으며
# 본
# 연구
# 에서
# 의
# 실행
# 경험
# 을
# 통하
# 여
# 학업
# 성적
# 이
# 비교
# 적
# 낮
# 은
# 초등학생
# 들
# 이
# 정규교
# 과
# 과정
# 과
# 연계
# 하
# ㄴ
# 로봇
# 교육
# 성공
# 가능
# 성
# 을
# 확인
# 하
# 였
# 다
# .
# 스크래치
# 프로그래밍
# 교육
# 이
# 초등학생
# 의
# 자기
# 주도
# 적
# 학습
# 능력
# 에
# 미치
# 는
# 효과
# 교육
# 용
# 프로그래밍
# 언어
# ,
# 스크래치
# 프로그램
# ,
# 자기
# 주도
# 적
# 학습
# 교육
# 용
# 프로그래밍
# 언어
# 에
# 대하
# ㄴ
# 선행
# 연구
# 에
# 따르
# 면
# 프로그래밍
# 교육
# 은
# 학습자
# 의
# 인지
# 기술
# ,
# 논리
# 적
# 사고력
# ,
# 반성
# 적
# 사고력향
# 상
# 에
# 도움
# 이
# 되
# 는
# 것
# 으로
# 나타나
# 았
# 다
# .
# 본
# 연구
# 에서
# 는
# 이러
# 하
# ㄴ
# 프로그래밍
# 교육
# 이
# 자
# 기
# 주도
# 적
# 학습
# 능력
# 에
# 미치
# 는
# 효과
# 에
# 대하
# 여
# 알아보
# 기
# 위하
# 여
# 스크래치
# 프로그래밍
# 교육
# 을
# 초등학교
# 6
# 학년
# 학생
# 들
# 에게
# 실시
# 하
# 였
# 다
# .
# 연구
# 결과
# 실험
# 집단
# 이
# 비교
# 집단
# 에
# 비하
# 여
# 자기
# 주도
# 적
# 학습
# 능력
# 의
# 하위
# 요소
# 이
# ㄴ
# 개방
# 성
# ,
# 내재
# 적
# 동기
# ,
# 자율
# 성
# 영역
# 의
# 신장
# 에
# 유의
# 하
# ㄴ
# 차이
# 를
# 보이
# 었
# 다
# .
# 이러
# 하
# ㄴ
# 효과
# 는
# 특히
# ICT
# 활용
# 능력
# 이
# 우수
# 하
# ㄴ
# 학생
# 들
# 에게
# 더욱
# 크
# 게
# 나타나
# 았
# 으며
# ,
# 그
# 향상
# 정도
# 는
# 기존
# 연구
# 에서
# 보고
# 하
# ㄴ
# 전자교과서
# ,
# UCC
# ,
# 사이버가
# 정학습
# 활동
# 후
# 의
# 자기
# 주도
# 적
# 학습
# 능력
# 향상
# 결과
# 보다
# 크
# ㄴ
# 것
# 으로
# 나타나
# 았
# 다
# .
# 초등학교
# 정보
# 교육
# 을
# 위하
# ㄴ
# EPL
# 적용
# 분석
# 초등학교
# 정보
# 교육
# ,
# EPL
# ,
# 교육
# 용
# 프로그래밍
# 언어
# 정보
# 교육
# 에서
# 프로그래밍
# 교육
# 은
# 프로그래밍
# 언어
# 를
# 이용
# 하
# 여
# 알고리즘
# 고안
# 과
# 문제
# 해결
# 을
# 수행
# 하
# 는데
# 그
# 의미
# 가
# 있
# 다
# .
# 그러나
# 프로그래밍
# 언어
# 도구
# 자체
# 를
# 익히
# 고
# 사용
# 하
# 는
# 것
# 이
# 선행
# 되
# 어야
# 하
# 기
# 에
# 초등학생
# 들
# 은
# 프로그래밍
# 언어
# 도구
# 를
# 익히
# 는
# 과정
# 을
# 거치
# 면서
# 그
# 흥미
# 가
# 점점
# 감소
# 되
# 고
# 있
# 는
# 실정
# 이
# 다
# .
# 이
# 에
# 보
# ㄴ
# 연구
# 에서
# 는
# 초등학생
# 들
# 이
# 프로그래밍
# 을
# Drag
# &
# Drop
# 방식
# 으로
# 쉽
# 게
# 사용
# 하
# ㄹ
# 수
# 있
# 고
# 결과물
# 을
# 프로그래밍
# 중
# 에
# 즉
# 시
# 확인
# 하
# ㄹ
# 수
# 있
# 는
# 교육
# 용
# 프로그래밍
# 언어
# (
# EPL
# )
# 를
# 이용
# 하
# 여
# 12
# 주
# 동안
# 매주
# 1
# 시간
# 씩
# 교육
# 하
# 기
# 위하
# ㄴ
# 학습
# 내용
# 을
# 구성
# 하
# 고
# 이
# 를
# 적용
# 하
# 였
# 다
# .
# 적용
# 결과
# ,
# EPL
# 은
# 초등학생
# 들
# 의
# 프로그래밍
# 교육
# 에
# 대하
# ㄴ
# 흥미
# 를
# 유발
# 및
# 유지
# 하
# ㄹ
# 수
# 있
# 고
# ,
# 창의력
# 과
# 논리력
# 신장
# 에
# 도
# 긍정
# 적
# 이
# ㄴ
# 영향
# 을
# 주
# ㄹ
# 수
# 있
# 는
# 것
# 으로
# 나타나
# 았
# 다
# .
# 소스
# 코드
# 차이
# 의
# 시각화
# 를
# 적용
# 하
# ㄴ
# 프로그래밍
# 원격
# 학습
# 원격
# 학습
# ,
# 시각
# 화
# ,
# 프로그래밍
# 언어
# 학습
# 원격
# 학습
# 을
# 통하
# 여서
# 교육
# 의
# 수요자
# 는
# 자신
# 의
# 필요
# 에
# 따르
# 아
# 어느
# 공간
# 에서
# 나
# 자신
# 이
# 편리
# 하
# ㄴ
# 시간
# 에
# 필요
# 하
# ㄴ
# 학습
# 을
# 하
# ㄹ
# 수
# 있
# 게
# 되
# 는데
# 효과
# 적
# 이
# ㄴ
# 학습
# 을
# 하
# 기
# 위하
# 여서
# ㄴ
# 학습
# 의
# 과정
# 과
# 결과
# 가
# 상호
# 보완
# 적
# 이
# 어야
# 하
# 고
# ,
# 교사
# 와
# 학생
# 간
# 에
# 즉
# 각
# 적
# 이
# ㄴ
# 상호
# 작용
# 이
# 이루
# 어
# 지
# ㄹ
# 수
# 있
# 어야
# 하
# ㄴ다
# .
# 이
# 를
# 가장
# 효율
# 적
# 으로
# 사용
# 하
# ㄹ
# 수
# 있
# 는
# 방법
# 으로
# 대
# 화
# 형
# 프로그램
# 에
# 프로그래밍
# 작성
# 화면
# 을
# 공유
# 하
# 여
# 교수자
# 와
# 학습자
# 가
# 대화
# 를
# 하
# 면서
# 프로그래밍
# 언어
# 학습
# 을
# 하
# ㄹ
# 수
# 있
# 도록
# 하
# 는
# 프로그램
# 을
# 구현
# 하
# 였
# 다
# .
# 본
# 연구
# 에서
# 는
# 학습자
# 가
# 교수자
# 의
# 수정
# 사항
# 을
# 시각
# 적
# 으로
# 확인
# 하
# ㄹ
# 수
# 있
# 도록
# 소스
# 코드
# 시각
# 화
# 기법
# 을
# 사용
# 하
# 여
# 학습자
# 가
# 효과
# 적
# 으로
# 수정
# 사항
# 을
# 인지
# 하
# ㄹ
# 수
# 있
# 게
# 하
# 였
# 다
# .
# 이
# 는
# 대
# 화
# 형
# 프로그램
# 의
# 장점
# 이
# ㄴ
# 사용자
# 간
# 의
# 상호
# 작용
# 을
# 프로그래밍
# 언어
# 교육
# 에
# 혼합
# 하
# ㄴ
# 것
# 으로
# 면
# 대
# 이
# 면
# 학습
# 효과
# 에
# 버금가
# 는
# 효과
# 가
# 나오
# ㄹ
# 것
# 이
# 라
# 기대
# 하
# ㄴ다
# .
# 안
# 드
# 로이
# 드
# 기반
# 입체
# 도형
# 학습
# 콘텐츠
# 제작
# 용
# 프레
# 임
# 워
# 크
# 의
# 설계
# 및
# 구현
# 안드
# 로이
# 드
# ,
# 입체
# 학습
# 콘텐츠
# ,
# 모바일러닝
# 보
# ㄴ
# 논문
# 은
# 스마트
# 기기
# 의
# 터치
# 인터페이스
# 를
# 활용
# 하
# 여
# 학습자
# 가
# 직접
# 입체
# 학습
# 콘텐츠
# 를
# 제어
# 하
# ㅁ
# 으로써
# 보다
# 실감
# 적
# 이
# ㄴ
# 교육
# 환경
# 을
# 구축
# 하
# 고자
# 하
# ㄴ다
# .
# 또한
# 기존
# 의
# 입체
# 학습
# 콘텐츠
# 는
# 제작
# 의
# 어려움
# 으로
# 인하
# 여
# 콘텐츠
# 확보
# 와
# 제공
# 에
# 한계
# 가
# 있
# 어
# 교사
# 및
# 학습자
# 가
# 직접
# 콘텐츠
# 를
# 제작
# 하
# 고
# 공유
# 하
# ㄹ
# 수
# 있
# 도록
# 프레
# 임워크
# 를
# 설계
# 하
# 였
# 다
# .
# 프레
# 임
# 워
# 크
# 는
# 직관
# 적
# 이
# ㄴ
# XML
# 언어
# 로
# 구성
# 되
# 고
# 안드로이
# 드
# 가
# 탑재
# 되
# ㄴ
# 기기
# 에서
# 재생
# 및
# 저작
# 이
# 가능
# 하
# 도록
# 어플리케이션
# 을
# 구현
# 하
# 였
# 으며
# 콘텐츠
# 공유
# 를
# 위하
# ㄴ
# 서버
# 환경
# 도
# 구축
# 하
# 였
# 다
# .
# 제안
# 하
# ㄴ
# 프레
# 임
# 워
# 크
# 는
# 전문가
# 평가
# 를
# 통하
# 여
# 타당
# 성
# 을
# 검증
# 하
# ㄴ
# 결과
# 새롭
# ㄴ
# 학습
# 콘텐츠
# 활용
# 가능
# 성
# 면
# 에서
# 긍정
# 적
# 으로
# 분석
# 되
# 었
# 다
# .
# 비판
# 적
# 사고
# 신장
# 을
# 위하
# ㄴ
# 협력
# 위키
# 시스템
# 오픈
# 커뮤니티
# ,
# 위키
# 시스템
# ,
# 비판
# 적
# 사고
# ,
# 협력
# 활동
# ,
# 웹
# 2
# .
# 0
# 시스템
# 이
# 연구
# 에서
# 는
# 비판
# 적
# 사고력
# 과
# 협력
# 활동
# 신장
# 을
# 위하
# 여
# 개방
# 형
# 커뮤니티
# 시스템
# 을
# 구축
# 하
# 고
# 학생
# 들
# 에게
# 적용
# 하
# 여
# 그
# 효과
# 에
# 대하
# 여
# 조사
# 하
# 였
# 다
# .
# 개방
# 형
# 커뮤니티
# 로
# 위키
# 시스템
# 을
# 이용
# 하
# 였
# 으며
# 비판
# 적
# 사고
# 와
# 협력
# 활동
# 향상
# 의
# 비교
# 를
# 위하
# 여
# 일반
# 게시판
# 을
# 활용
# 하
# 여
# 비평
# 적
# 글
# 쓰
# 기
# 수업
# 활동
# 을
# 하
# 였
# 다
# .
# 수업
# 적용
# 결과
# 일반
# 게시판
# 을
# 활용
# 하
# ㄴ
# 수업
# 보
# 다
# 개방
# 형
# 커뮤니티
# 이
# ㄴ
# 위키
# 시스템
# 에서
# 비판
# 적
# 사고
# 향상
# 의
# 결과
# 를
# 보이
# 었
# 다
# .
# 또한
# 개인
# 적
# 으로
# 활동
# 하
# 는
# 수업
# 보다
# 팀
# 별
# 로
# 협력
# 작업
# 을
# 하
# 는
# 수업
# 에서
# 비판
# 적
# 사고
# 활동
# 이
# 향상
# 되
# ㅁ
# 을
# 알
# ㄹ
# 수
# 있
# 었
# 다
# .
# 향후
# 위키
# 기반
# 개방
# 형
# 시스템
# 을
# 활용
# 하
# ㄴ
# 수업
# 을
# 진행
# 하
# ㄴ다면
# 비판
# 적
# 사고
# 와
# 같
# 은
# 고급
# 사고력
# 의
# 능력
# 이
# 높
# 아
# 지
# ㄹ
# 것
# 으로
# 기대
# 되
# ㄴ다
# .
# 로봇
# 교육
# 을
# 위하
# ㄴ
# 로봇
# 기술
# 자격증
# 현황
# 및
# 제언
# STEM
# ,
# 창의
# 성
# ,
# 로봇
# 교육
# ,
# 로봇
# 경진
# 대회
# ,
# 영재
# 교육
# ,
# 로봇
# 기술
# 자격증
# 국내
# 외
# 적
# 으로
# STEM
# 교육
# 과
# 창의
# 성
# 신장
# 에
# 관심
# 이
# 높
# 아
# 지
# ㅁ
# 에
# 따르
# 아
# 로봇
# 교육
# 이
# 주목
# 받
# 고
# 있
# 으며
# ,
# 우리나라
# 는
# 최근
# 초등학교
# 방
# 과
# 후
# 교실
# ,
# 로봇
# 경진
# 대회
# ,
# 영재
# 교육
# 등
# 을
# 중심
# 으로
# 매우
# 활발
# 하
# 게
# 이루어지
# 고
# 있
# 다
# .
# 이
# 에
# 따르
# 아
# 로봇
# 에
# 대하
# ㄴ
# 전문
# 지식
# 을
# 객관
# 적
# 으로
# 평가
# 하
# 기
# 위하
# ㄴ
# 기준
# 을
# 제시
# 하
# 고자
# 로봇
# 기술
# 자격시험
# 이
# 개발
# 되
# 어
# ,
# 초등학생
# 에서
# 일반
# 이
# ㄴ
# 가
# 지
# 그
# 응시
# 규모
# 가
# 해
# 마다
# 늘
# 어
# 국가
# 공인
# 자격증
# 으로서
# 의
# 준비
# 를
# 하
# 고
# 있
# 다
# .
# 그러나
# 방과
# 후학교
# 로봇교실
# 이
# 활성
# 화
# 이
# ㄴ데
# 반하
# 여
# ,
# 아직
# 로봇
# 기술
# 자격시험
# 에
# 대하
# ㄴ
# 초중등교사
# 에
# 대하
# ㄴ
# 인식
# 은
# 매우
# 부족
# 하
# ㄴ
# 상태
# 이
# 다
# .
# 따라서
# 보
# ㄴ
# 연구
# 에서
# 는
# 로봇
# 기술
# 자격시험
# 의
# 추진
# 배경
# 및
# 검정
# 기준
# ,
# 자격증
# 운영
# 조직
# ,
# 내용
# 및
# 출제
# 방향
# ,
# 급수
# 별
# 검정
# 내용
# ,
# 응시자
# 현황
# 분석
# 및
# 요구
# 를
# 조사
# 하
# 였
# 다
# .
# 로봇
# 기술
# 자격증
# 의
# 현황
# 을
# 살펴보
# ㄴ
# 바
# ,
# 문제
# 의
# 난이
# 도
# 및
# 측정
# 내용
# 에서
# 개선
# 요구
# 사항
# 이
# 많
# 은
# 것
# 으로
# 나타나
# 아
# 학생
# 들
# 의
# 수준
# 에
# 맞
# 는
# 적절
# 하
# ㄴ
# 교재
# 와
# 학생
# 들
# 의
# 다양
# 하
# ㄴ
# 로봇
# 기술
# 을
# 측정
# 하
# ㄹ
# 수
# 있
# 는
# 다양
# 하
# ㄴ
# 내용
# 이
# 뒷받침
# 이
# 필요
# 하
# 며
# ,
# 방
# 과
# 후
# 교실
# 과
# 연계
# 하
# 여
# 자격증
# 시험
# 을
# 확대
# 하
# 는
# 등
# 의
# 향후
# 로봇
# 교육
# 의
# 객관
# 적
# 인지
# 적
# 평가
# 기준
# 으로서
# 자리매김
# 하
# 기
# 위하
# ㄴ
# 제언
# 을
# 제시
# 하
# 였
# 다
# .
# 스캐폴딩
# 기반
# 학습
# 전략
# 이
# 스크래치
# 프로그래밍
# 학습
# 태도
# 에
# 미치
# 는
# 영향
# 스크래치
# ,
# 프로그래밍
# 학습
# ,
# 스캐폴딩
# ,
# 학습
# 태도
# 프로그래밍
# 교육
# 은
# 컴퓨터
# 과학
# 의
# 중요
# 성
# 이
# 부각
# 되
# ㅁ
# 에
# 따르
# 아
# 필요
# 성
# 이
# 증대
# 되
# 고
# 있
# 다
# .
# 그러나
# 기존
# 의
# 컴퓨터
# 교육
# 은
# 문제
# 해결
# 과정
# 보다
# 는
# 상용
# 프로그램
# 의
# 사용법
# 에
# 치우치
# 어
# 있
# 었
# 다
# .
# 또한
# 초등학교
# 에서
# 의
# 프로그래밍
# 교육
# 은
# 학생
# 들
# 의
# 수준
# 에
# 맞
# 지
# 않
# 거나
# 흥미
# 를
# 유발
# 하
# 지
# 못하
# 였
# 다
# .
# 본
# 연구
# 에서
# 는
# 초등학교
# 학생
# 들
# 에게
# 스크래치
# 프로그래밍
# 언어
# 로
# 프로그래밍
# 을
# 교육
# 하
# ㄹ
# 때
# 스캐폴딩
# 기반
# 학습
# 전략
# 을
# 적용
# 하
# ㄴ
# 후
# 학생
# 들
# 의
# 프로그래밍
# 학습
# 태도
# 를
# 관찰
# 하
# 였
# 다
# .
# 스캐폴딩
# 기반
# 학습
# 전략
# 을
# 적용
# 하
# ㄴ
# 결과
# 학생
# 들
# 은
# 프로그래밍
# 에
# 대하
# ㄴ
# 학습
# 태도
# 에서
# 일반
# 학습
# 경
# 향성
# ,
# 학습
# 을
# 통하
# ㄴ
# 성과
# 의
# 만족
# 도
# 및
# 상호
# 작용
# 항목
# 에서
# 모두
# 향상
# 되
# ㄴ
# 결과
# 를
# 보이
# 어
# 주
# 었
# 다
# .
# 언플러그드
# 컴퓨팅
# 과
# EPL
# 을
# 이용
# 하
# ㄴ
# 초등
# 정보
# 영재교육프로그램
# 의
# 개발
# 정보
# 영재
# ,
# 언플러그드
# 컴퓨팅
# ,
# 교육
# 용
# 프로그래밍
# 언어
# ,
# 정보
# 영재
# 교육프로그램
# 보
# ㄴ
# 연구
# 에서
# 정보
# 영재
# 를
# 교육
# 하
# 기
# 위하
# ㄴ
# 새롭
# ㄴ
# 방법
# 으로
# 언플러그드
# 컴퓨팅
# 과
# EPL
# 을
# 이용
# 하
# ㄴ
# 심화
# 교육
# 프로그램
# 을
# 제안
# 하
# 였
# 다
# .
# 먼저
# 언플러그드
# 컴퓨팅
# 교육
# 을
# 분석
# 하
# 고
# EPL
# 을
# 활용
# 하
# ㄴ
# 정보
# 영재
# 교육
# 을
# 위하
# ㄴ
# 심화
# 프로그램
# 을
# 개발
# 하
# 였
# 다
# .
# 개발
# 되
# ㄴ
# 영재
# 교육
# 프로그램
# 의
# 교육
# 과정
# 과
# 수업
# 전략
# 을
# 마련
# 하
# 였
# 다
# .
# 그리고
# 정보
# 영재
# 학급
# 의
# 초등학생
# 들
# 을
# 대상
# 으로
# 언플러그드
# 컴퓨팅
# 심화
# 교육
# 프로그램
# 을
# 적용
# 하
# 였
# 다
# .
# 개발
# 되
# ㄴ
# 영재
# 교육
# 프로그램
# 의
# 효과
# 성
# 을
# 검증
# 하
# 기
# 위하
# 여
# IT
# 기반
# 지식
# 과
# 알고리즘
# 에
# 대하
# ㄴ
# 사전
# 사후
# t
# -
# 검증
# 을
# 실시
# 하
# 였
# 다
# .
# 그
# 결과
# 언플러그드
# 컴퓨팅
# 교육
# 프로그램
# 을
# 적용
# 하
# ㄴ
# 반
# 이
# 사후
# 검증
# 에서
# 유
# 의미
# 하
# ㄴ
# 수준
# 으로
# 성취도
# 가
# 향상
# 되
# ㄴ
# 것
# 을
# 보
# ㄹ
# 수
# 있
# 었
# 다
# .
# 따라서
# 보
# ㄴ
# 연구
# 에서
# 개발
# 하
# ㄴ
# 언플러그드
# 컴퓨팅
# 교육
# 프로그램
# 은
# 향후
# 정보
# 영재
# 를
# 위하
# ㄴ
# 교육
# 프로그램
# 에
# 효과
# 적
# 으로
# 적용
# 되
# ㄹ
# 것
# 으로
# 기대
# 되
# ㄴ다
# .
# 중등
# 정보
# 교사
# 의
# 교수
# 내용
# 지식
# (
# PCK
# )
# 인식
# 수준
# 에
# 대하
# ㄴ
# 연구
# 정보
# 교육
# ,
# 교수
# 내용
# 지식
# 본
# 연구
# 의
# 목적
# 은
# 정보
# 교사
# 의
# 전문
# 성
# 을
# 향상
# 시키
# 기
# 위하
# ㄴ
# 지식
# 기반
# 의
# 일환
# 으로
# 현재
# 중등
# 정보
# 교사
# 의
# 교수
# 내용
# 지식
# (
# PCK
# )
# 에
# 대하
# ㄴ
# 인식
# 수준
# 을
# 파악
# 하
# 여
# 연구
# 의
# 기초
# 자료
# 를
# 마련
# 하
# 는데
# 있
# 다
# .
# 이
# 를
# 위하
# 여
# 교수
# 내용
# 지식
# (
# PCK
# )
# 에
# 대하
# ㄴ
# 이론
# 적
# 배경
# 을
# 바탕
# 으로
# 정보
# 교사
# 의
# 교수
# 내용
# 지식
# (
# PCK
# )
# 의
# 하위
# 범주
# 를
# 6
# 개
# 영역
# 으로
# 나누
# 고
# ,
# 전문가
# 검토
# 를
# 통하
# 여
# 31
# 개
# 의
# 문항
# 으로
# 수정
# ·
# 보완
# 하
# 여
# 현직
# 중등
# 정보
# 교사
# 34
# 명
# 을
# 대상
# 으로
# 설문
# 을
# 실시
# 하
# 여
# 결과
# 를
# 분석
# 하
# 였
# 다
# .
# 분석
# 결과
# 교수
# 내용
# 지식
# (
# PCK
# )
# 영역
# 전체
# 의
# 평균
# 점수
# 는
# 3
# .
# 87
# 이
# 었
# 다
# .
# 또한
# ,
# 경력
# 에
# 따르
# ㄴ
# 중등
# 정보
# 교사
# 들
# 의
# 교수
# 내용
# 지식
# (
# PCK
# )
# 인식
# 수준
# 은
# 교육
# 과정
# 지식
# 에
# 대하
# 여서
# 10
# 년
# 미만
# 이
# ㄴ
# 교사
# 집단
# 과
# 10
# 년
# 이상
# 이
# ㄴ
# 교사
# 집단
# 이
# 유의수준
# .
# 05
# 에서
# 유의미
# 하
# ㄴ
# 차이
# 가
# 있
# 었
# 다
# .
# 교육
# 용
# 로봇
# 을
# 활용
# 하
# ㄴ
# STEM
# 통합
# 교육
# 이
# 학업
# 성취
# ,
# 교과
# 태도
# 에
# 미치
# 는
# 효과
# STEM
# 통합
# 교육
# ,
# 로봇
# 교육
# 이
# 연구
# 는
# 교육
# 용
# 로봇
# 을
# 활용
# 하
# ㄴ
# STEM
# 통합
# 교육
# 이
# 학업
# 성취
# ,
# 교과
# 태도
# 에
# 미치
# 는
# 효과
# 를
# 알아보
# 기
# 위하
# 여
# 수행
# 되
# 었
# 다
# .
# 연구
# 대상
# 은
# 초등학교
# 6
# 학년
# 2
# 개
# 반
# 73
# 명
# 을
# 선정
# 하
# 였
# 으며
# ,
# 실험
# 집단
# 은
# 교육
# 용
# 로봇
# 을
# 활용
# 하
# ㄴ
# STEM
# 통합
# 교육
# 을
# ,
# 통제
# 집단
# 은
# 교과서
# 중심
# 의
# 분과
# 형
# 수업
# 을
# 12
# 차시
# 동안
# 처치
# 하
# 였
# 다
# .
# 연구
# 의
# 결과
# 로
# 첫째
# ,
# 인지
# 적
# 영역
# 이
# ㄴ
# 수학
# ․과학
# 학업
# 성취
# 에
# 있
# 어서
# 교육
# 용
# 로봇
# 을
# 활용
# 하
# ㄴ
# STEM
# 통합
# 교육
# 은
# 교과서
# 중심
# 의
# 분과
# 형
# 수업
# 보다
# 더
# 효과
# 적
# 이
# 었
# 다
# .
# 특히
# ,
# 학업
# 성취
# 하위
# 요인
# 이
# ㄴ
# 지식
# ,
# 이해
# ,
# 적용
# 영역
# 으로
# 사후
# 검증
# 하
# ㄴ
# 결과
# 지식
# 영역
# 에서
# 는
# 두
# 집단
# 간
# 통계
# 적
# 으로
# 유의
# 하
# ㄴ
# 차이
# 가
# 없
# 었
# 으나
# ,
# 이해
# 와
# 적용
# 영역
# 에서
# 는
# 실험
# 집단
# 이
# 통계
# 적
# 으로
# 유의
# 하
# 게
# 향상
# 되
# ㅁ
# 을
# 확인
# 하
# ㄹ
# 수
# 있
# 었
# 다
# .
# 둘째
# ,
# 정의
# 적
# 영역
# 이
# ㄴ
# 교과
# 태도
# 수준
# 에
# 있
# 어서
# 실험
# 집단
# 이
# 통제
# 집단
# 에
# 비하
# 여
# 긍정
# 적
# 이
# ㄴ
# 영향
# 이
# 있
# 음
# 을
# 확인
# 하
# ㄹ
# 수
# 있
# 었
# 다
# .
# 교육
# 용
# 로봇
# 을
# 활용
# 하
# ㄴ
# STEM
# 통합
# 교육
# 은
# 현행
# 수학
# ․과학
# 교과
# 의
# 정의
# 적
# 영역
# 이
# ㄴ
# 흥미
# 를
# 보완
# 하
# ㄹ
# 수
# 있
# 는
# 하나
# 의
# 방법
# 이
# 되
# ㄹ
# 수
# 있
# 으리라
# 기대
# 하
# ㄴ다
# .
# 스크래치
# 프로그래밍
# 교육
# 이
# 초등학생
# 의
# 학습
# 몰입
# 과
# 프로그래밍
# 능력
# 에
# 미치
# 는
# 효과
# 스크래치
# ,
# 학습
# 몰입
# ,
# 프로그래밍
# 교육
# ,
# 컴퓨터
# 교육
# 교육
# 현장
# 에서
# 프로그래밍
# 교육
# 은
# 고등
# 사고력
# 향상
# 을
# 위하
# ㄴ
# 학습
# 보다
# 는
# 프로그래밍
# 의
# 개념
# 이나
# 기초
# 문법
# 의
# 주입
# 및
# 단순
# 반복
# 으로
# 진행
# 되
# 고
# 있
# 다
# .
# 따라서
# 학습자
# 들
# 이
# 프로그래밍
# 교육
# 에
# 대하
# 여
# 긍정
# 적
# 이
# ㄴ
# 흥미
# 를
# 가지
# 고
# 적극
# 참여
# 하
# 여
# 교육
# 적
# 이
# ㄴ
# 효과
# 를
# 거두
# ㄹ
# 수
# 있
# 는
# 새롭
# ㄴ
# 프로그래밍
# 교육
# 방안
# 에
# 대하
# ㄴ
# 모색
# 이
# 필요
# 하
# 다
# .
# 스크래치
# EPL
# (
# Educational
# Programming
# Languages
# )
# 은
# 블록
# 쌓
# 기
# 를
# 통하
# 여
# 프로그래밍
# 이
# 가능
# 하
# ㄴ
# 직관
# 적
# 이
# ㄴ
# 언어
# 로
# 초등학생
# 들
# 도
# 보다
# 쉽
# 게
# 프로그래밍
# 을
# 이해
# 하
# ㄹ
# 수
# 있
# 다
# .
# 스크래치
# 의
# 이런
# 특징
# 은
# 프로그래밍
# 교육
# 에
# 대하
# ㄴ
# 학습자
# 의
# 학습
# 몰입
# (
# Flow
# )
# 에
# 긍정
# 적
# 이
# ㄴ
# 영향
# 을
# 미치
# ㄹ
# 수
# 있
# 다
# .
# 따라서
# 보
# ㄴ
# 연구
# 에서
# 는
# 프로그래밍
# 교육
# 의
# 새롭
# ㄴ
# 방안
# 으로
# 스크래치
# 프로그래밍
# 교육
# 을
# 진행
# 하
# 고
# 초등학생
# 의
# 학습
# 몰입
# 과
# 프로그래밍
# 능력
# 에
# 미치
# 는
# 영향
# 에
# 대하
# 여
# 검증
# 하
# 고자
# 하
# ㄴ다
# .
# 본
# 연구
# 의
# 결과
# 스크래치
# 프로그래밍
# 교육
# 이
# 학습자
# 의
# 전반
# 적
# 이
# ㄴ
# 학습
# 몰입
# 수준
# 향상
# 에
# 긍정
# 적
# 이
# ㄴ
# 효과
# 가
# 있
# 음
# 을
# 알
# ㄹ
# 수
# 있
# 다
# 미래
# 사회
# 영재
# 판별
# 방법
# 에
# 관하
# ㄴ
# 연구
# 미래
# 사회
# 영재
# ,
# 영재
# 판별
# ,
# 영재선
# 발
# 영재
# 교육
# 에
# 있
# 어서
# 가장
# 중요
# 하
# ㄴ
# 문제
# 중
# 의
# 하나
# 는
# 영재
# 성
# 에
# 대하
# ㄴ
# 정의
# 와
# 영재
# 를
# 정확
# 하
# 게
# 판별
# 하
# 는
# 것
# 이
# 다
# .
# 영재
# 의
# 판별
# 은
# 영재
# 성
# 의
# 정의
# 에
# 근거
# 하
# 여야
# 하
# 는데
# ,
# 영
# 재
# 성
# 의
# 정의
# 는
# 사회
# 의
# 가치관
# 에
# 따르
# 아
# 다르
# 며
# ,
# 영
# 재
# 성
# 은
# 개념
# 적
# 이
# ㄴ
# 용어
# 이
# 므로
# 직접
# 적
# 으로
# 측정
# 하
# 기
# 어렵
# 기
# 때문
# 에
# 영재
# 를
# 판별
# 하
# 는
# 것
# 도
# 명확
# 하
# ㄴ
# 기준
# 에
# 따르
# ㄴ
# 객관
# 적
# 이
# 고
# 절대
# 적
# 이
# ㄴ
# 도구
# 는
# 존재
# 하
# 지
# 않
# 는다
# .
# 최근
# 영재
# 교육
# 이
# 상위
# 학교
# 진학
# 에
# 도움
# 이
# 되
# ㄴ다고
# 하
# 여
# 많
# 은
# 학부모
# 들
# 이
# 영재
# 교육
# 을
# 특목고
# 와
# 명문대
# 진학
# 을
# 위하
# ㄴ
# 발판
# 이나
# 수단
# 으로
# 생각
# 하
# 고
# 있
# 다
# .
# 본
# 연구
# 는
# 미래
# 사회
# 가
# 요구
# 하
# 는
# 영재
# 를
# 판별
# 하
# ㄹ
# 방안
# 을
# 개발
# 하
# 기
# 위하
# 여
# 영
# 재
# 선발
# 에
# 대하
# ㄴ
# 기초
# 적
# 이
# ㄴ
# 이해
# 를
# 바탕
# 으로
# ,
# 현행
# 영
# 재
# 선발
# 방법
# 의
# 문제점
# 을
# 분석
# 하
# 고
# 시사점
# 을
# 도출
# 하
# ㄴ
# 다음
# ,
# 이
# 를
# 활용
# 하
# ㄴ
# 판별
# 전략
# 과
# 선발
# 절차
# 및
# 방법
# 등
# 을
# 제안
# 하
# 고
# 있
# 다
# .
# 본
# 논문
# 에서
# 는
# 미래
# 사회
# 에
# 성공
# 하
# ㄹ
# 가능
# 성
# 이
# 많
# 은
# 영
# 재
# 를
# 선발
# 하
# 기
# 위하
# 여서
# 는
# 인지
# 적
# 이
# ㄴ
# 요소
# 외
# 에
# 정의
# 적
# 이
# ㄴ
# 요소
# 에
# 대하
# ㄴ
# 평가
# 가
# 이루어지
# 어야
# 하
# 며
# ,
# 영재
# 성
# 을
# 가지
# ㄴ
# 모든
# 영재
# 들
# 에게
# 영재
# 교육
# 의
# 기회
# 를
# 확대
# 하
# 고
# ,
# 영재
# 프로그램
# 배치
# 후
# 에
# 도
# 영재
# 성
# 에
# 대하
# ㄴ
# 평가
# 가
# 지속
# 적
# 으로
# 이루어지
# 어야
# 하
# ㅁ
# 을
# 밝히
# 고
# 있
# 다
# .
# 초등학생
# 을
# 위하
# ㄴ
# 스
# 토리텔링
# 기반
# 로봇
# 프로그래밍
# 교육
# 시스템
# 디지털
# 스토리텔링
# ,
# 로봇
# 교육
# 로봇
# 활용
# 프로그래밍
# 교육
# 은
# 학습자
# 의
# 흥미
# 유발
# 과
# 학습
# 성취
# 도
# 향상
# 에
# 의미
# 있
# 는
# 효과
# 가
# 있
# 다
# .
# 그러나
# 대부분
# 의
# 로봇
# 프로그래밍
# 이
# 단순
# 하
# ㄴ
# 문법
# 적
# 지식
# 습득
# 위주
# 로
# 구성
# 되
# 어
# 학습
# 후반
# 에
# 학습자
# 의
# 참여
# 도
# 가
# 현저히
# 떨어지
# 는
# 경향
# 이
# 있
# 다
# .
# 스토리텔링
# 은
# 자신
# 의
# 경험
# 에
# 바탕
# 을
# 두
# ㄴ
# 이야기
# 를
# 구성
# 하
# 고
# 논리
# 적
# 사고력
# 을
# 향상
# 시키
# ㄹ
# 수
# 있
# 는
# 다양
# 하
# ㄴ
# 교육
# 적
# 방법
# 을
# 제공
# 하
# 여
# 학습자
# 에게
# 긍정
# 적
# 학습
# 동기
# 를
# 부여
# 하
# ㄹ
# 수
# 있
# 다
# .
# 본
# 연구
# 는
# 스토리텔링
# 을
# 기반
# 으로
# 한
# 로봇
# 교육
# 과정
# 을
# 설계
# 하
# 고
# 이
# 를
# 지원
# 하
# ㄹ
# 수
# 있
# 는
# 시스템
# 을
# 개발
# 하
# 였
# 다
# .
# 개발
# 되
# ㄴ
# 로봇
# 교육
# 과정
# 과
# 시스템
# 은
# 학습자
# 의
# 이야기
# 구성
# 을
# 위하
# ㄴ
# 협력
# 적
# 지식
# 도구
# 와
# 로봇
# 프로그래밍
# 과정
# 을
# 시각
# 화
# 하
# ㄹ
# 수
# 있
# 는
# 도구
# 를
# 제공
# 하
# 여
# 지속
# 적
# 이
# ㄴ
# 학습
# 동기
# 부여
# 와
# 학업
# 성취
# 도
# 향상
# 에
# 도움
# 을
# 주
# ㄹ
# 것
# 이
# 다
# .
# 모바일
# 웹
# 서비스
# 성능
# 향상
# 처리기
# 설계
# 모바일
# 웹
# 서비스
# ,
# 성능
# 평가
# ,
# SOAP
# ,
# 자바
# 서블랫
# 보
# ㄴ
# 논문
# 에서
# 는
# 모바일
# 웹
# 서비스
# 구현
# 환경
# 을
# 최소
# 화
# 하
# 면서
# 서비스
# 성능
# 을
# 향상
# 시키
# 는
# 개선
# 되
# ㄴ
# 처리기
# 를
# 설계
# 제안
# 하
# 였
# 다
# .
# 웹
# 서비스
# 를
# 구현
# 하
# 기
# 위하
# 여서
# 는
# 표준
# 에
# 규정
# 되
# ㄴ
# WSDL
# 코드
# 를
# 가지
# 고
# SOAP
# 통신
# 을
# 하
# 여야
# 하
# ㄴ다
# .
# 그러므로
# WSDL
# 및
# SOAP
# 를
# 구현
# 하
# 면
# 기본
# 적
# 이
# ㄴ
# 웹
# 서비스
# 가
# 가능
# 하
# 다
# .
# 또한
# 웹
# 통신
# 을
# 위하
# 여
# Tomcat
# 과
# AXIS
# 라
# 이브러리
# 를
# 사용
# 하
# 여야
# 하
# ㄴ다
# .
# 그러나
# Tomcat
# 의
# 사용
# 은
# 추가
# 적
# 이
# ㄴ
# 네트워크
# 사용
# 과
# 시스템
# 에
# 프로세스
# 로
# 상주
# 하
# 여
# 시스템
# 자원
# 을
# 사용
# 하
# 는
# 문제
# 가
# 있
# 기
# 때문
# 에
# 구현
# 시
# 오버
# 헤드
# 를
# 발생
# 시키
# ㄹ
# 수
# 있
# 다
# .
# 본
# 논문
# 은
# 오
# 버
# 헤드
# 의
# 원인
# 이
# ㄴ
# Tomcat
# 을
# 사용
# 하
# 지
# 않
# 고
# 모바일
# 웹
# 서비스
# 를
# 구현
# 하
# ㅁ
# 으로써
# 네트워크
# 자원
# 과
# 시스템
# 자원
# 을
# 절약
# 하
# ㄹ
# 수
# 있
# 으면서
# 성능
# 을
# 향상
# 시키
# 는
# 효율
# 적
# 처리기
# 를
# 설계
# 구현
# 하
# 였
# 다
# .
# 초등학교
# 에서
# 로봇
# 활용
# 미술
# 수업
# 이
# 창의
# 성
# 신장
# 에
# 미치
# 는
# 효과
# 창의
# 성
# ,
# 로봇
# ,
# 미술
# 교육
# 보
# ㄴ
# 연구
# 는
# 초등학교
# 미술
# 수업
# 에서
# 로봇
# 활용
# 이
# 창의
# 성
# 에
# 미치
# 는
# 영향
# 에
# 대하
# 여
# 조사
# 하
# 였
# 다
# .
# 로봇
# 과
# 창의
# 성
# 관련
# 하
# ㄴ
# 선행
# 연구
# 및
# 초등학교
# 미술
# 교육
# 과정
# 분석
# 을
# 통하
# 여
# 로봇
# 활용
# 창의
# 적
# 미술
# 수업
# 프로그램
# 을
# 개발
# 하
# 였
# 으며
# 현장
# 에
# 16
# 차
# 시
# 를
# 투입
# 하
# 였
# 다
# .
# 연구
# 대상
# 은
# 초등학교
# 4
# 학년
# 으로
# 총
# 57
# 명
# 이
# 실험
# 에
# 참여
# 하
# 였
# 으며
# 사전
# 사후
# 창의
# 성
# 검사
# 결과
# 를
# 기초
# 로
# 공변량
# 검사
# 를
# 실시
# 하
# 였
# 다
# .
# 연구
# 결과
# 로봇
# 활용
# 미술
# 수업
# 에
# 참여
# 하
# ㄴ
# 학생
# 은
# 전통
# 적
# 이
# ㄴ
# 미술
# 수업
# 에
# 참여
# 하
# ㄴ
# 통제
# 집단
# 의
# 학생
# 보다
# 유의미
# 하
# ㄴ
# 수준
# 의
# 향상
# 되
# ㄴ
# 창의
# 성
# 점수
# 결과
# 를
# 얻
# 었
# 다
# .
# 이
# 와
# 같
# 은
# 결과
# 는
# 초등학교
# 미술
# 수업
# 에서
# 로봇
# 이
# 창의
# 성
# 신장
# 에
# 효과
# 적
# 이
# ㄴ
# 도구
# 이
# 라는
# 것
# 을
# 입증
# 하
# ㄴ다고
# 보
# ㄹ
# 수
# 있
# 다
# 확장
# 되
# ㄴ
# 정보
# 기술
# 수용
# 모델
# (
# TAM
# )
# 을
# 기반
# 으로
# 디지털교
# 과서
# 수용
# 및
# 활용
# 탐색
# 정보
# 기술
# 수용모형
# ,
# 디지털교
# 과서
# ,
# 교육
# 혁신
# 의
# 확산
# 이
# 연구
# 는
# 초․중등
# 교원
# 을
# 대상
# 으로
# 혁신
# 확산
# 모형
# 에서
# 제안
# 하
# 는
# 혁신
# 속성
# 변인
# 들
# 을
# 기반
# 으로
# 디지털교과서
# 의
# 수용
# 을
# 결정
# 하
# 는
# 요인
# 을
# 규명
# 하
# 고
# ,
# 정보
# 기술
# 수용
# 모형
# (
# TAM
# )
# 을
# 보다
# 확장
# 되
# ㄴ
# 모형
# 으로
# 제안
# 하
# 고
# 검증
# 하
# 고자
# 수행
# 되
# 었
# 다
# .
# 이
# 를
# 위하
# 여
# 관찰
# 가능
# 성
# ,
# 적합
# 성
# ,
# 주관
# 적
# 규범
# 을
# 외생
# 변인
# 으로
# ,
# 유용
# 성
# 과
# 사용
# 용
# 이
# 성
# ,
# 사용
# 의도
# 를
# 나
# 의
# 생변인
# 으로
# 설정
# 하
# 는
# 연구
# 모형
# 을
# 제안
# 하
# 였
# 다
# .
# 연구
# 결과
# 관찰
# 가능
# 성
# ,
# 적합
# 성
# ,
# 주관
# 적
# 규범
# 은
# 교사
# 의
# 디지털교
# 과
# 서
# 사용
# 의도
# 에
# 영향
# 을
# 미치
# 는
# 주
# 요
# 하
# ㄴ
# 외재
# 적
# 변인
# 이
# 며
# ,
# 본
# 연구
# 에서
# 제안
# 하
# ㄴ
# 확장
# 되
# ㄴ
# 정보
# 기술
# 수용모
# 형
# 은
# 적합
# 하
# ㅁ
# 을
# 검증
# 하
# 였
# 다
# .
# 2009
# 년
# 검정교과서
# 로
# 채택
# 되
# ㄴ
# ‘
# 정보
# ’
# 교과서
# ‘
# 문제
# 해결
# 방법
# 과
# 절차
# ’
# 영역
# 구성
# 의
# 탐구
# 적
# 경향
# 분석
# 문제
# 해결
# 방법
# 과
# 절차
# ,
# 탐구
# 적
# 경향
# ,
# Romey
# 분석
# 정보교
# 과
# 는
# 2007
# 년
# 개정
# 교육
# 과정
# 을
# 통하
# 여
# ‘
# 정보
# ’
# 로
# 과목
# 의
# 명칭
# 을
# 통일
# 하
# 고
# ,
# 교과
# 의
# 특성
# 을
# 반영
# 하
# ㄴ
# 문제
# 해결능력
# 을
# 중시
# 하
# 는
# 교육
# 으로
# 변화
# 를
# 거듭
# 하
# 였
# 다
# .
# 이
# 에
# 보
# ㄴ
# 연구
# 는
# ‘
# 정보
# ’
# 교과
# 의
# ‘
# 문제
# 해결
# 방법
# 과
# 절차
# ’
# 영역
# 이
# 학생
# 들
# 의
# 능력
# 을
# 높이
# 는
# 데
# 기여
# 하
# ㄹ
# 수
# 있
# 을
# 정도
# 의
# 탐구
# 적
# 경향
# 을
# 보이
# 는
# 지
# 알아보
# 았
# 다
# .
# 검정
# 교과서
# 중
# 채택
# 율
# 이
# 높
# 은
# 4
# 종
# 의
# 교과서
# 를
# Romey
# 분석법
# 으로
# 분석
# 하
# ㄴ
# 결과
# ,
# 본문
# 분석
# 에서
# 는
# 1
# 개
# 교과서
# 만
# 이
# 탐구
# 적
# 경향
# 을
# 보이
# ㄴ
# 반면
# ,
# 교과서
# 활동
# 지수
# 는
# 각
# 교과서
# 마다
# 충분
# 하
# ㄴ
# 정도
# 의
# 탐구
# 적
# 경향
# 을
# 나타내
# 었
# 다
# .
# 그러나
# 내용
# 의
# 구성
# 에
# 있
# 어서
# 사용
# 되
# ㄴ
# 소프트웨어
# 들
# 이
# 상용
# 이
# 거나
# 특정
# 프로그래밍
# 언어
# 에
# 귀속
# 되
# 는
# 문제
# 가
# 발견
# 되
# 었
# 다
# .
# 본
# 연구
# 는
# 학교
# 교육
# 에서
# 교과서
# 의
# 선택
# 만
# 으로
# 도
# 내재
# 적
# 불
# 평등
# 의
# 가능
# 성
# 이
# 제기
# 되
# ㄹ
# 수
# 있
# 으므로
# 교과서
# 는
# 최대한
# 객관
# 적
# 으로
# 기술
# 되
# 어야
# 하
# 고
# 특정
# 학습
# 환경
# 에
# 종속
# 되
# 지
# 않
# 도록
# 구성
# 되
# 어야
# 하
# ㅁ
# 을
# 시사점
# 으로
# 발견
# 하
# ㄹ
# 수
# 있
# 었
# 다
# .
# 초등
# 교사
# 의
# 저작
# 권
# 지식
# 수준
# 분석
# 을
# 통하
# ㄴ
# 교육
# 정보
# 이용
# 활성
# 화
# 방안
# 연구
# 저작
# 권
# ,
# 저작
# 권
# 지식
# ,
# 교육
# 정보
# 학교
# 현장
# 에서
# 교육
# 정보
# 의
# 활용
# 이
# 증가
# 하
# 면서
# ,
# 교사
# 및
# 학교
# 를
# 대상
# 으로
# 하
# ㄴ
# 저작
# 권
# 법
# 위반
# 피소
# 사례
# 또한
# 증가
# 하
# 고
# 있
# 다
# .
# 따라서
# 교사
# 대상
# 의
# 저작
# 권
# 교육
# 이
# 다양
# 하
# 게
# 이루어지
# 고
# 있
# 으나
# ,
# 교사
# 들
# 의
# 교육
# 정보
# 에
# 대하
# ㄴ
# 인식
# 이나
# 저작
# 권
# 에
# 대하
# ㄴ
# 지식
# 수준
# 등
# 에
# 대하
# ㄴ
# 연구
# 는
# 미비
# 하
# ㄴ
# 편
# 이
# 다
# .
# 이
# 에
# 보
# ㄴ
# 연구
# 는
# 초등
# 교사
# 349
# 명
# 을
# 대상
# 으로
# ,
# 교사
# 들
# 이
# 인지
# 하
# 고
# 있
# 어야
# 하
# ㄹ
# 저작
# 권
# 관련
# 지식
# 을
# 측정
# 하
# 였
# 다
# .
# 분석
# 결과
# ,
# 저작
# 권
# 교육
# 여부
# 보다
# 는
# 교육
# 용
# 콘텐츠
# 제작
# 경험
# 여부
# 에
# 따르
# 아
# 저작
# 권
# 지식
# 은
# 차이
# 를
# 보이
# 었
# 다
# .
# 즉
# ,
# 저작
# 권
# 교육
# 을
# 받
# 았
# 다
# 하
# ㄹ지라도
# 자신
# 의
# 필요
# 에
# 의하
# 여
# 활용
# 되
# 었
# 을
# 때
# ,
# 해당
# 지식
# 이
# 더
# 높
# 아
# 지
# ㅁ
# 을
# 알
# ㄹ
# 수
# 있
# 었
# 다
# .
# 본
# 연구
# 는
# 저작
# 권
# 교육
# 이
# 하나
# 의
# 지식
# 으로
# 교육
# 되
# 기
# 보
# 다
# 는
# 교육
# 정보
# 가
# 활용
# 되
# 는
# 상황
# 에
# 적합
# 하
# ㄴ
# 저작
# 권
# 교육
# 이
# 더
# 효과
# 적
# 이
# ㄹ
# 것
# 이
# 라는
# 시사점
# 을
# 제공
# 하
# 였
# 다
# .
# 학습
# 장애아
# 의
# 읽
# 기
# 능력
# 향상
# 을
# 위하
# ㄴ
# PREP
# 기반
# 의
# 모바일
# 학습
# 시스템
# 설계
# 및
# 구현
# 학습
# 장애아
# ,
# PREP
# ,
# 모바일
# 학습
# 시스템
# 학습
# 장애아
# 의
# 읽
# 기
# 능력
# 을
# 위하
# ㄴ
# PREP
# (
# PASS
# Reading
# Enhancement
# Program
# )
# 는
# 학습
# 장애아
# 를
# 대상
# 으로
# 하
# ㄴ
# 관찰
# 을
# 바탕
# 으로
# 이론
# 이
# 정립
# 되
# 었
# 고
# ,
# 인지
# 기능
# 에
# 비
# 인
# 지
# 적
# 요소
# 이
# ㄴ
# 주의
# 집중
# 을
# 포함
# 시키
# 고
# 있
# 어
# 여러
# 연구
# 를
# 통하
# 여서
# 그
# 효과
# 가
# 입증
# 되
# 었
# 다
# .
# 그러나
# PREP
# 를
# 활용
# 하
# ㄴ
# 모바일
# 시스템
# 의
# 연구
# 는
# 초기
# 단계
# 에
# 있
# 어
# 보
# ㄴ
# 연구
# 는
# 인지
# 이론
# 을
# 바탕
# 으로
# 하
# ㄴ
# 프로그램
# 이
# ㄴ
# PREP
# 를
# 활용
# 하
# 여
# 모바일
# 학습
# 시스템
# 을
# 설계
# 하
# 고
# 구현
# 하
# 였
# 다
# .
# 본
# 시스템
# 의
# 특징
# 은
# 다음
# 과
# 같
# 다
# .
# 첫째
# ,
# 연속
# 적
# 과제
# 와
# 동시
# 적
# 과제
# 를
# 학습
# 내용
# 으로
# 하
# 여
# 학습
# 전략
# 을
# 발전
# 시키
# 며
# 읽
# 기
# 기능
# 을
# 향상
# 시키
# 는
# 데
# 중점
# 을
# 두
# 었
# 다
# .
# 둘째
# ,
# 학습자
# 의
# 특성
# 을
# 반영
# 하
# 여
# 흥미
# 를
# 유지
# 하
# ㄹ
# 수
# 있
# 도록
# 퀴즈
# 의
# 형식
# 을
# 도입
# 하
# 고
# 학습자
# 의
# 접근
# 성
# 과
# 이동
# 성
# ,
# 개별
# 성
# 을
# 강화
# 하
# ㄴ
# 시스템
# 을
# 고려
# 하
# 여
# 설계
# 하
# 고
# 구현
# 하
# 였
# 다
# .
# 셋째
# ,
# 시스템
# 을
# 사용
# 시
# 학습자
# 의
# 수준
# 에
# 따르
# 아
# 다른
# 단계
# 로
# 접근
# 이
# 가능
# 하
# 며
# 완전
# 학습
# 을
# 지원
# 하
# ㄹ
# 수
# 있
# 는
# 인터페이스
# 를
# 구현
# 하
# 여
# 학습자
# 의
# 유
# 의
# 미
# 하
# ㄴ
# 읽
# 기
# 능력
# 이
# 가능
# 하
# 도록
# 설계
# 하
# 고
# 구현
# 하
# 였
# 다
# .
# 본
# 시스템
# 을
# 학습
# 장애
# 의
# 초등학생
# 에게
# 적용
# 하
# ㄴ
# 결과
# ,
# 읽기
# 활동
# 에
# 대하
# ㄴ
# 태도
# 와
# 읽
# 기
# 능력
# 이
# 모바일
# 학습
# 시스템
# 을
# 적용
# 하
# 기
# 전
# 보다
# 향상
# 되
# 어
# PREP
# 프로그램
# 의
# 효과
# 성
# 이
# 입증
# 되
# 었
# 다
# .
# 문서
# 특성
# 에
# 대하
# ㄴ
# 선호
# 도
# 기반
# 웹
# 검색
# 개인
# 화
# 정보
# 필터링
# ,
# 웹
# 개인
# 화
# ,
# 협력
# 필터링
# ,
# 추천
# 시스템
# 웹
# 상
# 에서
# 사용자
# 가
# 원하
# 는
# 정보
# 를
# 효율
# 적
# 으로
# 검색
# 하
# 는데
# 도움
# 을
# 주
# 기
# 위하
# 여
# 웹
# 개인
# 화
# 는
# 사용자
# 에게
# 흥미
# 있
# 는
# 웹
# 문서
# 들
# 을
# 추출
# 하
# 여
# 내
# 는
# 데
# 초점
# 을
# 두
# 고
# 있
# 다
# .
# 이
# 를
# 실현
# 하
# 기
# 위하
# ㄴ
# 주요
# 방법
# 들
# 중
# 하나
# 는
# 문서
# 에
# 포함
# 되
# ㄴ
# 질의어
# ,
# 링
# 크
# 및
# 사용자
# 의
# 선호어
# 를
# 이용
# 하
# 는
# 것
# 이
# 다
# .
# 본
# 연구
# 에서
# 는
# 이
# 들
# 요소
# 외
# 에
# 사용자
# 들
# 이
# 웹문서
# 를
# 선택
# 하
# ㄹ
# 때
# 중요
# 하
# 게
# 생각
# 하
# 는
# 문서
# 특성
# 들
# 을
# 설문
# 을
# 통하
# 여
# 조사
# 하
# 였
# 다
# .
# 설문
# 결과
# 문서
# 의
# 내용
# 이
# 가장
# 중요
# 하
# ㄴ
# 특성
# 이
# 었
# 으나
# ,
# 일부
# 사용자
# 들
# 에게
# 는
# 문서
# 에
# 포함
# 되
# ㄴ
# 이미지
# 와
# 가
# 독
# 성
# 도
# 내용
# 과
# 마찬가지
# 로
# 중요
# 하
# 게
# 간주
# 되
# 었
# 다
# .
# 이
# 를
# 바탕
# 으로
# 각
# 사용자
# 를
# 위하
# ㄴ
# 문서
# 의
# 주요
# 특성
# 들
# 의
# 상대
# 적
# 가중
# 치
# 를
# 프로필
# 에
# 유지
# 관리
# 하
# 고
# ,
# 검색
# 결과
# 의
# 개인
# 화
# 에
# 반영
# 하
# 는
# 방안
# 을
# 제시
# 하
# ㄴ다
# .
# 제안
# 하
# ㄴ
# 개인
# 화
# 방법
# 의
# 성능
# 을
# 분석
# 하
# ㄴ
# 결과
# ,
# 일반
# 검색
# 엔진
# 에
# 비하
# 여
# 최대
# 약
# 2
# .
# 3
# 배
# 의
# 성능
# 향상
# 을
# 보이
# 었
# 고
# ,
# 사용자
# 질의어
# 와
# 선호어
# 를
# 모두
# 이용
# 하
# 여
# 검색
# 결과
# 를
# 산출
# 하
# 는
# 방법
# 보다
# 약
# 1
# .
# 5
# 배
# 의
# 성능
# 향상
# 을
# 나타내
# 어
# 그
# 우수
# 성
# 을
# 입증
# 하
# 였
# 다
# .
# 국가
# 경쟁력
# 향상
# 을
# 위하
# ㄴ
# 정보
# 교육
# 진흥법
# 제정
# 의
# 필요
# 성
# 과
# 입법
# 방향
# 정보
# 교육
# 진흥법
# ,
# 정보
# 교육
# 활성
# 화
# 방안
# ,
# 정보
# 교육
# 실태
# ,
# IT
# 산업
# 실태
# 보
# ㄴ
# 우리나라
# 는
# 전
# 세계
# IT
# 생산량
# 의
# 7
# %
# 를
# 차지
# 하
# 는
# IT
# 강국
# 이
# 지만
# 정보
# 교육
# 을
# 소홀
# 이
# 다루
# 고
# 있
# 어
# 핵심
# 원천
# 기술
# 과
# SW
# 를
# 개발
# 하
# ㄹ
# 인력
# 이
# 부족
# 하
# ㄴ
# 형편
# 이
# 다
# .
# 따라서
# 보
# ㄴ
# 논문
# 에서
# 는
# 열악
# 하
# ㄴ
# 교육
# 체제
# 를
# 개선
# 하
# 고
# 정보
# 교육
# 을
# 활성
# 화
# 하
# 기
# 위하
# ㄴ
# 정보
# 교육
# 진흥법
# 의
# 제정
# 방안
# 을
# 제안
# 하
# 였
# 다
# .
# 그리고
# 이법
# 에서
# 담
# 아야
# 하
# ㄹ
# 내용
# 으로
# 체계
# 적
# 이
# 고
# 안정
# 적
# 이
# ㄴ
# 정보
# 교육
# 의
# 활성
# 화
# 를
# 위하
# ㄴ
# 국가
# 와
# 지방
# 자치
# 단체
# 의
# “
# 정보
# 교
# 육
# 종합
# 계획
# 수립
# ”
# 에
# 대하
# ㄴ
# 책무
# ,
# 정보
# 교육
# 의
# 활성
# 화
# 를
# 추진
# 하
# 기
# 위하
# ㄴ
# 위원회
# 구성
# ,
# 학교
# 교육
# 과
# 사회
# 교육
# 에서
# 의
# 정보
# 교육
# 활성
# 화
# 방안
# ,
# 정보
# 활용
# 능력인증제
# 도입
# 등
# 에
# 대하
# ㄴ
# 구체
# 적
# 이
# ㄴ
# 방안
# 을
# 제시
# 하
# 였
# 다
# .
# 따라서
# 보
# ㄴ
# 논문
# 을
# 통하
# 여
# 도출
# 되
# 는
# 연구
# 결과
# 는
# 침체
# 되
# 어
# 있
# 는
# 우리나라
# 의
# 정보
# 교육
# 을
# 활성
# 화
# 하
# ㄹ
# 수
# 있
# 는
# 정보
# 교육
# 진흥법
# 제정
# 의
# 방향
# 을
# 제시
# 하
# 여
# 주
# 는
# 지표
# 가
# 되
# ㄹ
# 수
# 있
# 을
# 것
# 으로
# 기대
# 하
# ㄴ다
# .
# 언플러그드
# 에
# 듀테
# 인
# 먼트
# 교육
# 프로그램
# 의
# 개발
# 에
# 듀
# 테
# 인먼트
# ,
# 컴퓨터
# 과학
# 언플러그드
# ,
# 컴퓨터
# 과학
# 교육
# 교육
# 대학교
# 학생
# 을
# 대상
# 으로
# 설문
# 결과
# 절반
# 이상
# 의
# 학생
# 이
# 정보
# 교육
# 이
# 초등
# 교육
# 에서
# 중요
# 하
# 지
# 않
# 다고
# 인식
# 을
# 하
# 고
# 있
# 으며
# ,
# 실제
# 수업
# 에서
# 도
# 배우
# 는데
# 많
# 은
# 어려움
# 을
# 호소
# 하
# 고
# 있
# 다
# .
# 이러
# 하
# ㄴ
# 인식
# 의
# 전환
# 과
# 컴퓨터
# 수업
# 의
# 어려움
# 을
# 해결
# 하
# 기
# 위하
# 여
# 이
# 연구
# 에서
# 컴퓨터
# 과학
# 언플러그드기반
# 의
# 에듀테인먼트
# 프로그램
# 을
# 제안
# 하
# 였
# 다
# .
# 에
# 듀테
# 인
# 먼트
# 요소
# 가
# 포함
# 되
# ㄴ
# 컴퓨터
# 과학
# 교육
# 프로그램
# 을
# 개발
# 하
# 고
# 수업
# 전략
# 을
# 마련
# 하
# 였
# 다
# .
# 제안
# 하
# ㄴ
# 프로그램
# 을
# 수업
# 에
# 적용
# 하
# ㄴ
# 결과
# 학생
# 들
# 의
# 인식
# 전환
# 과
# 함께
# 수업
# 을
# 가치
# 있
# 게
# 느끼
# 었
# 으며
# ,
# 학습
# 주도
# 성
# 뿐만
# 아니
# 라
# 학습
# 성취도
# 에서
# 도
# 비교반
# 보다
# 우수
# 하
# ㄴ
# 결과
# 를
# 보이
# 었
# 다
# .
# 따라서
# 보
# ㄴ
# 연구
# 에서
# 제안
# 하
# ㄴ
# 컴퓨터
# 과학
# 언플러그드기반
# 에듀테인먼트
# 프로그램
# 이
# 교육
# 대학교
# 의
# 컴퓨터
# 과학
# 교육
# 에서
# 효과
# 적
# 으로
# 활용
# 되
# ㄹ
# 것
# 으로
# 기대
# 되
# ㄴ다
# .
# 선행
# 조직자
# 를
# 적용
# 하
# ㄴ
# 프로그래밍
# 학습
# 이
# 초등학생
# 의
# 논리
# 적
# 사고력
# 과
# 자기
# 효능감
# 에
# 미치
# 는
# 영향
# 선행
# 조직자
# ,
# 초등
# 프로그래밍
# 학습
# ,
# 논리
# 적
# 사고력
# ,
# 자
# 기
# 효능감
# 보
# ㄴ
# 연구
# 는
# 초등학교
# 현장
# 에서
# 선행
# 조직자
# 를
# 적용
# 하
# ㄴ
# 프로그래밍
# 학습
# 이
# 초등학생
# 의
# 논리
# 적
# 사고력
# 과
# 자기
# 효능감
# 에
# 미치
# 는
# 영향
# 을
# 분석
# 하
# 여
# 그
# 효과
# 성
# 을
# 검증
# 하
# 는
# 데
# 목적
# 이
# 있
# 다
# .
# 이
# 에
# 보
# ㄴ
# 연구
# 에서
# 는
# 논리
# 적
# 사고력
# 과
# 자기
# 효능감
# 을
# 향상
# 시키
# ㄹ
# 수
# 있
# 는
# 선행
# 조직자
# 를
# 개발
# 하
# 고
# 이
# 를
# 초등
# 현장
# 에
# 적용
# 하
# 여
# 그
# 효과
# 성
# 을
# 분석
# 하
# 였
# 다
# .
# 본
# 연구
# 의
# 검증
# 을
# 위하
# 여
# 초등학교
# 4
# 학년
# 두
# 학급
# 을
# 전통
# 적
# 이
# ㄴ
# 프로그래밍
# 학습
# 을
# 하
# 는
# 통제
# 집단
# 과
# 선행
# 조직자
# 를
# 적용
# 하
# ㄴ
# 프로그래밍
# 학습
# 을
# 하
# 는
# 실험
# 집단
# 으로
# 나누
# 어
# 수업
# 을
# 실시
# 하
# 였
# 다
# .
# 효과
# 성
# 을
# 검증
# 하
# 기
# 위하
# 여
# 사전
# 사후
# t
# -
# 검증
# 을
# 하
# 였
# 고
# ,
# 그
# 결과
# 두
# 집단
# 간
# 의
# 논리
# 적
# 사고력
# 과
# 자기
# 효능감
# 에서
# 유의미
# 하
# ㄴ
# 차이
# 를
# 나타내
# 었
# 다
# .
# 정보
# 통신
# 윤리
# 교육
# 을
# 위하
# ㄴ
# 블랜디드
# 문제
# 중심
# 학습
# 시스템
# 설계
# 및
# 구현
# 정보
# 통신
# 윤리
# 교육
# ,
# 블랜디드
# 문제
# 중심
# 학습
# 본
# 논문
# 의
# 목적
# 은
# 정보
# 통신
# 윤리
# 교육
# 을
# 위하
# ㄴ
# 효과
# 적
# 이
# ㄴ
# 블랜디드
# 문제
# 중심
# 학습
# 시스템
# 을
# 구현
# 하
# 는
# 데
# 있
# 다
# .
# 제안
# 시스템
# 은
# 온라인
# 학습
# 과
# 면대면
# 수업
# 이
# 체계
# 적
# 으로
# 혼합
# 되
# 었
# 고
# 온라인
# 학습
# 플랫폼
# 을
# 위하
# 여서
# 무
# 들
# 을
# 활용
# 하
# 였
# 다
# .
# 위키
# 와
# 블로그
# 를
# 지식
# 의
# 생성
# 뿐
# 만
# 아니
# 라
# 문제
# 중심
# 학습
# 을
# 지원
# 하
# 기
# 위하
# ㄴ
# 능동
# 적
# 학습
# 도구
# 로
# 활용
# 하
# 였
# 다
# .
# 제안
# 시스템
# 에서
# 학습자
# 가
# 새롭
# ㄴ
# 지식
# 생성
# 과
# 문제
# 해결
# 능력
# 향상
# ,
# 협동
# 학습
# 의
# 이해
# 와
# 같
# 은
# 문제
# 중심
# 학습
# 의
# 다양
# 하
# ㄴ
# 효과
# 들
# 을
# 체험
# 하
# 기
# 위하
# ㄴ
# 열리
# ㄴ
# 공간
# 으로서
# 의
# 웹
# 2
# .
# 0
# 을
# 활용
# 하
# 였
# 다
# .
# 블랜디드
# 문제
# 중심
# 학습
# 시스템
# 은
# 교수
# -
# 학습
# 모형
# 과
# 함께
# 정보
# 통신
# 윤리
# 학습
# 에서
# 학습자
# 의
# 수업
# 만족도
# 와
# 학업
# 성취도
# 가
# 평가
# 되
# 었
# 다
# .
# 연구
# 결과
# 를
# 보
# 면
# 블랜디드
# PBL
# 학습
# 방법
# 이
# 면
# 대
# 이
# 면
# PBL
# 학습
# 방법
# 보다
# 정보
# 통신
# 윤리
# 의식
# 함양
# 에
# 효과
# 적
# 이
# 었
# 으며
# 면대
# 이
# 면
# PBL
# 학습
# 방법
# 보다
# 학습자
# 들
# 의
# 만족도
# 와
# 학업
# 성취도
# 가
# 높
# 았
# 다
# .
# 디지털
# 스
# 토리텔링
# 을
# 적용
# 하
# ㄴ
# 게임중독
# 치료
# 교육
# 프로그램
# 의
# 개발
# 인터넷
# 중독
# ,
# 게임
# 중독
# ,
# 게임중독
# 치료
# 프로그램
# ,
# 디지털스토리텔링
# 교육
# 이
# 연구
# 는
# 게임
# 중독
# 치료
# 를
# 위하
# ㄴ
# 새롭
# ㄴ
# 접근
# 으로
# 디지털스토리텔링
# 을
# 활용
# 하
# ㄴ
# 교육
# 프로그램
# 의
# 개발
# 전략
# 을
# 제안
# 하
# 였
# 다
# .
# 우선
# 디
# 지털
# 스
# 토리텔링
# 수업
# 을
# 위하
# ㄴ
# 교육
# 내용
# 을
# 5
# 가지
# 멀티미디어
# 요소
# 로
# 선정
# 하
# 고
# 게임
# 중독
# 치료
# 를
# 위하
# ㄴ
# 교육
# 전략
# 과
# 절차
# 를
# 마련
# 하
# 였
# 다
# .
# 5
# 명
# 의
# 게임
# 중독
# 위험군
# 학생
# 을
# 선발
# 하
# 여
# 개발
# 되
# ㄴ
# 프로그램
# 을
# 적용
# 하
# 였
# 고
# 게임
# 중독
# 검사
# ,
# 게임
# 이용
# 시간
# 검사
# ,
# 회기
# 별
# 관찰
# 과
# 면담
# ,
# 제안
# 되
# ㄴ
# 프로그램
# 의
# 효과
# 성
# 검사
# 를
# 실시
# 하
# 였
# 다
# .
# 검사
# 결과
# ,
# 제안
# 되
# ㄴ
# 프로그램
# 이
# 게임중독
# 경
# 향
# 성
# 의
# 감소
# 에
# 긍정
# 적
# 이
# ㄴ
# 효과
# 를
# 가져오
# 았
# 고
# ,
# 디지털
# 스
# 토리텔링
# 전략
# 의
# 효과
# 분석
# 에서
# 디지털스토리텔링
# 과정
# 을
# 통하
# 여
# 느끼
# 는
# 몰입감
# ,
# 참여
# 와
# 도전
# ,
# 사회
# 적
# 상호
# 작용
# ,
# 성취도
# 가
# 높
# 은
# 것
# 으로
# 나타나
# 았
# 다
# .
# 제안
# 되
# ㄴ
# 디지털
# 스
# 토리텔링
# 프로그램
# 은
# 게임중독
# 치료
# 에
# 긍정
# 적
# 이
# ㄴ
# 역할
# 을
# 하
# ㄹ
# 수
# 있
# 을
# 것
# 으로
# 기대
# 하
# ㄴ다
# .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-d49b0c888e40> in <module>
# ----> 1 tokenized = data["kor_full"].apply(lambda row: khaiiiTokenizer(row))
#       2 #print(tokenized)
#       3 tokenized.to_excel("./final_data/1206token_khaiii_full.xls") ##############
#       4 print("========= tokenization completed =========")
#
# ~/Library/Python/3.8/lib/python/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4210             else:
#    4211                 values = self.astype(object)._values
# -> 4212                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4213
#    4214         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-22-d49b0c888e40> in <lambda>(row)
# ----> 1 tokenized = data["kor_full"].apply(lambda row: khaiiiTokenizer(row))
#       2 #print(tokenized)
#       3 tokenized.to_excel("./final_data/1206token_khaiii_full.xls") ##############
#       4 print("========= tokenization completed =========")
#
# <ipython-input-21-df8c39e47bbd> in khaiiiTokenizer(raw, stopword, pos)
#       3     list = []
#       4
# ----> 5     for word in api.analyze(raw): #raw data
#       6         #print(word)
#       7
#
# ~/Library/Python/3.8/lib/python/site-packages/khaiii/khaiii.py in analyze(self, in_str, opt_str)
#     221         """
#     222         assert self._handle >= 0
# --> 223         results = self._lib.khaiii_analyze(self._handle, in_str.encode('UTF-8'),
#     224                                            opt_str.encode('UTF-8'))
#     225         if not results:
#
# KeyboardInterrupt:

# %%
#lda
id2word = gensim.corpora.Dictionary(tokenized)
# Out:
# /Users/uni613/Library/Python/3.8/lib/python/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
wordlist = []
for i in range(len(id2word)):
    #print(id2word[i])
    wordlist.append(id2word[i])
#print(wordlist)
seriesWordlist = pd.Series(wordlist)
seriesWordlist.to_excel("./final_data/1206wordlist_khaiii_full.xls") #################

corpus=[id2word.doc2bow(text) for text in tokenized]
#print("id2word for each document : ", corpus)
print("# words in total : ", len(id2word))
print("# documents : ", len(corpus))
